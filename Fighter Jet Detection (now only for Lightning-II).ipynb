# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8m.pt')

# %%
model.train(data="C:/Users/szymo/Desktop/aircraft.v1i.yolov8/data.yaml", epochs=5)
# Out:
# New https://pypi.org/project/ultralytics/8.1.4 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200  Python-3.11.4 torch-2.1.0+cpu CPU (Intel Core(TM) i5-9300H 2.40GHz)
# ...
